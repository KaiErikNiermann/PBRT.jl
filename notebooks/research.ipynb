# %%
import numpy as np 
import matplotlib.pyplot as plt
import pandas as pd
import seaborn as sns
from scipy.stats import norm

# %%
df = pd.read_csv('data/gpu.csv')
# Convert the Date column to datetime
df['Date'] = pd.to_datetime(df['Date'])


# convert gflops to tflops
df['GFLOPS'] = df['GFLOPS'] / 1000

# Create the scatter plot
plt.figure(figsize=(10, 6))
plt.scatter(df['Date'], df['GFLOPS'], c='blue', label='GFLOPS')

# Set labels and title
plt.xlabel('Release Date')
plt.ylabel('TFLOPS')
plt.title('GPU Performance Over Time')

# Set x-ticks with 10 evenly spaced intervals
plt.xticks(pd.date_range(start=df['Date'].min(), end=df['Date'].max(), periods=10))

# Rotate x-tick labels for better readability
plt.xticks(rotation=45)

# Show legend
plt.legend()

# Display the plot
plt.show()

# %%
df = pd.read_csv('data/Book1.csv')

# %%
# Calculate average grade per TA
average_grades = df.groupby('TA')['grade'].mean().reset_index()

# Sort the average grades in descending order
sorted_average_grades = average_grades.sort_values(by='grade', ascending=False)

# set the id as the index
sorted_average_grades.set_index('TA', inplace=True)

print(sorted_average_grades)
# Out:
#                grade
# TA
# Gregory     7.484167
# Tadas       6.637647
# Vlad        6.625833
# Laura S     6.518182
# Davit       6.431250
# Sudarsan    6.411667
# Simon       6.355556
# Lennart     6.337500
# Alexis      6.155000
# Dovydas     6.108636
# Shreyas     5.971500
# Tom         5.517917
# Elena       5.428636
# Anca        5.377500
# Robert      5.330556
# Tiziano     5.269444
# Nico        5.074583
# Laura D     5.069000
# Maria       5.039000
# Lara        4.895417
# Zain        4.766667
# Minh        4.742500
# Stef        4.707647
# Ricardo     4.597500
# Rico        4.388636
# Kai         4.178500
# Gesualdo    4.046250
# Max         3.919167
# Alessandro  3.741053
# Riccardo    3.390625

# %%
# Plot grade distribution
plt.figure(figsize=(8, 6))
plt.hist(df['grade'], bins=50, edgecolor='black')
plt.title('Grade Distribution for Students')
plt.xlabel('Grade')
plt.ylabel('Frequency')
plt.grid(True)
plt.show()
