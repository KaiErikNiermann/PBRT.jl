# %%
using Pkg 
Pkg.add("GeometryBasics")
using GLMakie
using LinearAlgebra

# Function to calculate circumcircle in 2D
function circumcircle_2d(A, B, C)
    S_x = (1 / 2) * det([norm(A)^2 norm(B)^2 norm(C)^2 ; A[2] B[2] C[2] ; 1 1 1])
    S_y = (1 / 2) * det([A[1] B[1] C[1] ; norm(A)^2 norm(B)^2 norm(C)^2 ; 1 1 1])
    a = det([A[1] A[2] 1 ; B[1] B[2] 1 ; C[1] C[2] 1])
    b = det([A[1] A[2] norm(A)^2 ; B[1] B[2] norm(B)^2 ; C[1] C[2] norm(C)^2])

    circumcenter = (S_x / a, S_y / a)
    circumradius = sqrt((b / a) + norm([S_x, S_y])^2 / a^2)

    return circumcenter, circumradius
end

# Define the points of the 3D polygon
points_3d = [[12.726414, 13.161091, 1.224224], [12.666434, 12.797903, 0.384936], [12.565, 14.635716, -1.034951]]

# Single vertex in 3D
point_3d = [[12.565362, 14.635716, -1.029877]]

# Define the points of the 2D polygon
points_2d = [[-2.128461043458973, 13.161091], [-1.2870325276485568, 12.797903], [0.1364729854478327, 14.635716]]

# Single point in 2D
point_2d = [[0.13138608860044054, 14.635716]]

# Calculate circumcircle for 2D polygon
center_2d, radius_2d = circumcircle_2d(points_2d[1], points_2d[2], points_2d[3])

# Create a Figure
fig = Figure()

# convert from vector to vertices 
points_3d = [Point3f0(p...) for p in points_3d]
point_3d = [Point3f0(p...) for p in point_3d]
points_2d = [Point2f0(p...) for p in points_2d]
point_2d = [Point2f0(p...) for p in point_2d]
center_2d = Point2f0(center_2d)
points_2d = [Point2f0(p...) for p in points_2d]

# Add a 3D axis to the figure for the 3D polygon
ax3d = Axis3(fig[1, 1])
# Plot the 3D polygon using the mesh function
mesh!(ax3d, points_3d)
# Plot the 3D point on the 3D axis
scatter!(ax3d, point_3d)

# Add a 2D axis to the figure for the 2D polygon
ax2d = Axis(fig[1, 2])
# Plot the 2D polygon using the poly function
poly!(ax2d, points_2d)
# Plot the 2D point on the 2D axis
scatter!(ax2d, point_2d)

# Plot the circumcircle in 2D
circumcircle_2d_points = [(center_2d[1] + radius_2d * cos(t), center_2d[2] + radius_2d * sin(t)) for t in 0:0.01:2pi]
lines!(ax2d, circumcircle_2d_points)

# Display the figure
fig

# %%
using Pkg
Pkg.add("GeometryBasics")
using GLMakie
using LinearAlgebra
using Statistics
using GeometryBasics

struct Triangle 
    A::Vector{Float64}
    B::Vector{Float64}
    C::Vector{Float64}
end

points_3d = [[12.726414, 13.161091, 1.224224], [12.666434, 12.797903, 0.384936], [12.565, 14.635716, -1.034951], [12.565362, 14.635716, -1.029877]]

# %%
using Base
using LinearAlgebra
using GeometryBasics
using Distributions

include("util.jl")
include("interval.jl")
include("ray.jl")
include("material.jl")
include("hittable.jl")
include("aabb.jl")
include("sphere.jl")
include("triangle.jl")
include("hittable_list.jl")
include("bvh.jl") 
include("camera.jl")
include("scene.jl")

include("obj_reader.jl")
# Out:
# triangulation

# %%
obj_file = "../scenes/cottage_obj.obj"
sc = reader(obj_file)

world_l = hittable_list()

for face in sc.f_array
    if length(face.vertices) == 3
        t1 = Triangle(face.vertices[1], face.vertices[2], face.vertices[3], lambertian(color([0.0, 0.0, 0.8])))
        push!(world_l, t1)
    elseif length(face.vertices) == 4
        triangles = split_quad(face.vertices)
        for t in triangles
            push!(world_l, t)
        end
    else
        println("Unexpected face vertex count: ", length(face.vertices))
    end
end

println("World length: ", length(world_l.objects))
# Out:
# mtllib cottage_obj.mtl
# o ground_Plane.004
# usemtl ground
# s off
# o light_3_Plane.003
# usemtl light_1
# s off
# o light_1_Plane.002
# usemtl light_1
# s off
# o light_2_Plane.001
# usemtl light_1
# s off
# o Cube_Cube.002
# usemtl cottage_texture
# s off
# Unexpected face vertex count: 0
# Unexpected face vertex count: 0
# Unexpected face vertex count: 0
# Unexpected face vertex count: 0
# World length: 478

# %%
triangle_to_point = [[Point3f0(t.A...), Point3f0(t.B...), Point3f0(t.C...)] for t in world_l.objects]

# render triangles using meshes 
using GLMakie
function render_triangles(triangles)
    fig = Figure()
    ax = Axis3(fig[1, 1])
    for t in triangles
        mesh!(ax, t)
    end
    fig
end

render_triangles(triangle_to_point)

# %%
node = bvh_node()
bvh_tree = bvh_node(world_l, node)

node_list = []
tree_list = []

function print_bvh(world, indent = "")
	# if type is a bvh node 
	if typeof(world) == bvh_node
		println(indent, "BVH Node:")
		println(indent, "├─ Left:")
		print_bvh(world.left, indent * "│  ")
		println(indent, "└─ Right:")
		print_bvh(world.right, indent * "   ")
	else
		println(indent, world)
		push!(node_list, world)
	end
end

print_bvh(bvh_tree)

world_obj_list = world_l.objects

println("Node list length: ", length(node_list))
println("World object list length: ", length(world_obj_list))
# Out:
# BVH Node:
# ├─ Left:
# │  BVH Node:
# │  ├─ Left:
# │  │  BVH Node:
# │  │  ├─ Left:
# │  │  │  BVH Node:
# │  │  │  ├─ Left:
# │  │  │  │  BVH Node:
# │  │  │  │  ├─ Left:
# │  │  │  │  │  BVH Node:
# │  │  │  │  │  ├─ Left:
# │  │  │  │  │  │  BVH Node:
# │  │  │  │  │  │  ├─ Left:
# │  │  │  │  │  │  │  BVH Node:
# │  │  │  │  │  │  │  ├─ Left:
# │  │  │  │  │  │  │  │  BVH Node:
# │  │  │  │  │  │  │  │  ├─ Left:
# │  │  │  │  │  │  │  │  │  Triangle(id = 7750897276446883)
# │  │  │  │  │  │  │  │  └─ Right:
# │  │  │  │  │  │  │  │     Triangle(id = 7750897276446883)
# │  │  │  │  │  │  │  └─ Right:
# │  │  │  │  │  │  │     BVH Node:
# │  │  │  │  │  │  │     ├─ Left:
# │  │  │  │  │  │  │     │  Triangle(id = 7962893983632590)
# │  │  │  │  │  │  │     └─ Right:
# │  │  │  │  │  │  │        Triangle(id = 9698853332601627)
# │  │  │  │  │  │  └─ Right:
# │  │  │  │  │  │     BVH Node:
# │  │  │  │  │  │     ├─ Left:
# │  │  │  │  │  │     │  BVH Node:
# │  │  │  │  │  │     │  ├─ Left:
# │  │  │  │  │  │     │  │  Triangle(id = 9234238333093025)
# │  │  │  │  │  │     │  └─ Right:
# │  │  │  │  │  │     │     Triangle(id = 2699057816433474)
# │  │  │  │  │  │     └─ Right:
# │  │  │  │  │  │        BVH Node:
# │  │  │  │  │  │        ├─ Left:
# │  │  │  │  │  │        │  Triangle(id = 7124523463926090)
# │  │  │  │  │  │        └─ Right:
# │  │  │  │  │  │           Triangle(id = 8795741491562452)
# │  │  │  │  │  └─ Right:
# │  │  │  │  │     BVH Node:
# │  │  │  │  │     ├─ Left:
# │  │  │  │  │     │  BVH Node:
# │  │  │  │  │     │  ├─ Left:
# │  │  │  │  │     │  │  BVH Node:
# │  │  │  │  │     │  │  ├─ Left:
# │  │  │  │  │     │  │  │  Triangle(id = 121826572489077)
# │  │  │  │  │     │  │  └─ Right:
# │  │  │  │  │     │  │     Triangle(id = 121826572489077)
# │  │  │  │  │     │  └─ Right:
# │  │  │  │  │     │     BVH Node:
# │  │  │  │  │     │     ├─ Left:
# │  │  │  │  │     │     │  Triangle(id = 251057960426916)
# │  │  │  │  │     │     └─ Right:
# │  │  │  │  │     │        Triangle(id = 7739395618097232)
# │  │  │  │  │     └─ Right:
# │  │  │  │  │        BVH Node:
# │  │  │  │  │        ├─ Left:
# │  │  │  │  │        │  BVH Node:
# │  │  │  │  │        │  ├─ Left:
# │  │  │  │  │        │  │  Triangle(id = 8999443061235475)
# │  │  │  │  │        │  └─ Right:
# │  │  │  │  │        │     Triangle(id = 2860412306781887)
# │  │  │  │  │        └─ Right:
# │  │  │  │  │           BVH Node:
# │  │  │  │  │           ├─ Left:
# │  │  │  │  │           │  Triangle(id = 2908137203348215)
# │  │  │  │  │           └─ Right:
# │  │  │  │  │              Triangle(id = 3341077537515447)
# │  │  │  │  └─ Right:
# │  │  │  │     BVH Node:
# │  │  │  │     ├─ Left:
# │  │  │  │     │  BVH Node:
# │  │  │  │     │  ├─ Left:
# │  │  │  │     │  │  BVH Node:
# │  │  │  │     │  │  ├─ Left:
# │  │  │  │     │  │  │  BVH Node:
# │  │  │  │     │  │  │  ├─ Left:
# │  │  │  │     │  │  │  │  Triangle(id = 6292150896617102)
# │  │  │  │     │  │  │  └─ Right:
# │  │  │  │     │  │  │     Triangle(id = 6292150896617102)
# │  │  │  │     │  │  └─ Right:
# │  │  │  │     │  │     BVH Node:
# │  │  │  │     │  │     ├─ Left:
# │  │  │  │     │  │     │  Triangle(id = 923026540314870)
# │  │  │  │     │  │     └─ Right:
# │  │  │  │     │  │        Triangle(id = 4260714118754063)
# │  │  │  │     │  └─ Right:
# │  │  │  │     │     BVH Node:
# │  │  │  │     │     ├─ Left:
# │  │  │  │     │     │  BVH Node:
# │  │  │  │     │     │  ├─ Left:
# │  │  │  │     │     │  │  Triangle(id = 4212209238798693)
# │  │  │  │     │     │  └─ Right:
# │  │  │  │     │     │     Triangle(id = 6246298080142573)
# │  │  │  │     │     └─ Right:
# │  │  │  │     │        BVH Node:
# │  │  │  │     │        ├─ Left:
# │  │  │  │     │        │  Triangle(id = 7155078097623868)
# │  │  │  │     │        └─ Right:
# │  │  │  │     │           Triangle(id = 9284541793433046)
# │  │  │  │     └─ Right:
# │  │  │  │        BVH Node:
# │  │  │  │        ├─ Left:
# │  │  │  │        │  BVH Node:
# │  │  │  │        │  ├─ Left:
# │  │  │  │        │  │  BVH Node:
# │  │  │  │        │  │  ├─ Left:
# │  │  │  │        │  │  │  Triangle(id = 5454854699763601)
# │  │  │  │        │  │  └─ Right:
# │  │  │  │        │  │     Triangle(id = 8632190714914750)
# │  │  │  │        │  └─ Right:
# │  │  │  │        │     BVH Node:
# │  │  │  │        │     ├─ Left:
# │  │  │  │        │     │  Triangle(id = 3701372504326290)
# │  │  │  │        │     └─ Right:
# │  │  │  │        │        Triangle(id = 4312119195707665)
# │  │  │  │        └─ Right:
# │  │  │  │           BVH Node:
# │  │  │  │           ├─ Left:
# │  │  │  │           │  BVH Node:
# │  │  │  │           │  ├─ Left:
# │  │  │  │           │  │  Triangle(id = 3243771683065033)
# │  │  │  │           │  └─ Right:
# │  │  │  │           │     Triangle(id = 8439939049158092)
# │  │  │  │           └─ Right:
# │  │  │  │              BVH Node:
# │  │  │  │              ├─ Left:
# │  │  │  │              │  Triangle(id = 4003438956735276)
# │  │  │  │              └─ Right:
# │  │  │  │                 Triangle(id = 615354952599850)
# │  │  │  └─ Right:
# │  │  │     BVH Node:
# │  │  │     ├─ Left:
# │  │  │     │  BVH Node:
# │  │  │     │  ├─ Left:
# │  │  │     │  │  BVH Node:
# │  │  │     │  │  ├─ Left:
# │  │  │     │  │  │  BVH Node:
# │  │  │     │  │  │  ├─ Left:
# │  │  │     │  │  │  │  BVH Node:
# │  │  │     │  │  │  │  ├─ Left:
# │  │  │     │  │  │  │  │  Triangle(id = 3536794115286035)
# │  │  │     │  │  │  │  └─ Right:
# │  │  │     │  │  │  │     Triangle(id = 3536794115286035)
# │  │  │     │  │  │  └─ Right:
# │  │  │     │  │  │     BVH Node:
# │  │  │     │  │  │     ├─ Left:
# │  │  │     │  │  │     │  Triangle(id = 8607068914079405)
# │  │  │     │  │  │     └─ Right:
# │  │  │     │  │  │        Triangle(id = 2155171139831324)
# │  │  │     │  │  └─ Right:
# │  │  │     │  │     BVH Node:
# │  │  │     │  │     ├─ Left:
# │  │  │     │  │     │  BVH Node:
# │  │  │     │  │     │  ├─ Left:
# │  │  │     │  │     │  │  Triangle(id = 482716386060097)
# │  │  │     │  │     │  └─ Right:
# │  │  │     │  │     │     Triangle(id = 3705368031678710)
# │  │  │     │  │     └─ Right:
# │  │  │     │  │        BVH Node:
# │  │  │     │  │        ├─ Left:
# │  │  │     │  │        │  Triangle(id = 3799409278374205)
# │  │  │     │  │        └─ Right:
# │  │  │     │  │           Triangle(id = 3313293192960362)
# │  │  │     │  └─ Right:
# │  │  │     │     BVH Node:
# │  │  │     │     ├─ Left:
# │  │  │     │     │  BVH Node:
# │  │  │     │     │  ├─ Left:
# │  │  │     │     │  │  BVH Node:
# │  │  │     │     │  │  ├─ Left:
# │  │  │     │     │  │  │  Triangle(id = 4935341764238044)
# │  │  │     │     │  │  └─ Right:
# │  │  │     │     │  │     Triangle(id = 4961865923210224)
# │  │  │     │     │  └─ Right:
# │  │  │     │     │     BVH Node:
# │  │  │     │     │     ├─ Left:
# │  │  │     │     │     │  Triangle(id = 8263571466163620)
# │  │  │     │     │     └─ Right:
# │  │  │     │     │        Triangle(id = 4644250992945337)
# │  │  │     │     └─ Right:
# │  │  │     │        BVH Node:
# │  │  │     │        ├─ Left:
# │  │  │     │        │  BVH Node:
# │  │  │     │        │  ├─ Left:
# │  │  │     │        │  │  Triangle(id = 9713652026057836)
# │  │  │     │        │  └─ Right:
# │  │  │     │        │     Triangle(id = 4488608865091709)
# │  │  │     │        └─ Right:
# │  │  │     │           BVH Node:
# │  │  │     │           ├─ Left:
# │  │  │     │           │  Triangle(id = 4723990300888155)
# │  │  │     │           └─ Right:
# │  │  │     │              Triangle(id = 5325863681929711)
# │  │  │     └─ Right:
# │  │  │        BVH Node:
# │  │  │        ├─ Left:
# │  │  │        │  BVH Node:
# │  │  │        │  ├─ Left:
# │  │  │        │  │  BVH Node:
# │  │  │        │  │  ├─ Left:
# │  │  │        │  │  │  BVH Node:
# │  │  │        │  │  │  ├─ Left:
# │  │  │        │  │  │  │  Triangle(id = 5763537634712605)
# │  │  │        │  │  │  └─ Right:
# │  │  │        │  │  │     Triangle(id = 5763537634712605)
# │  │  │        │  │  └─ Right:
# │  │  │        │  │     BVH Node:
# │  │  │        │  │     ├─ Left:
# │  │  │        │  │     │  Triangle(id = 9023661048723044)
# │  │  │        │  │     └─ Right:
# │  │  │        │  │        Triangle(id = 2992435051182671)
# │  │  │        │  └─ Right:
# │  │  │        │     BVH Node:
# │  │  │        │     ├─ Left:
# │  │  │        │     │  BVH Node:
# │  │  │        │     │  ├─ Left:
# │  │  │        │     │  │  Triangle(id = 4487424958417631)
# │  │  │        │     │  └─ Right:
# │  │  │        │     │     Triangle(id = 4399059046978678)
# │  │  │        │     └─ Right:
# │  │  │        │        BVH Node:
# │  │  │        │        ├─ Left:
# │  │  │        │        │  Triangle(id = 8847652839411295)
# │  │  │        │        └─ Right:
# │  │  │        │           Triangle(id = 6451312478543429)
# │  │  │        └─ Right:
# │  │  │           BVH Node:
# │  │  │           ├─ Left:
# │  │  │           │  BVH Node:
# │  │  │           │  ├─ Left:
# │  │  │           │  │  BVH Node:
# │  │  │           │  │  ├─ Left:
# │  │  │           │  │  │  Triangle(id = 928923607865733)
# │  │  │           │  │  └─ Right:
# │  │  │           │  │     Triangle(id = 9625891441439381)
# │  │  │           │  └─ Right:
# │  │  │           │     BVH Node:
# │  │  │           │     ├─ Left:
# │  │  │           │     │  Triangle(id = 5912446136881100)
# │  │  │           │     └─ Right:
# │  │  │           │        Triangle(id = 9990682402364419)
# │  │  │           └─ Right:
# │  │  │              BVH Node:
# │  │  │              ├─ Left:
# │  │  │              │  BVH Node:
# │  │  │              │  ├─ Left:
# │  │  │              │  │  Triangle(id = 6130091009094157)
# │  │  │              │  └─ Right:
# │  │  │              │     Triangle(id = 7834813010557156)
# │  │  │              └─ Right:
# │  │  │                 BVH Node:
# │  │  │                 ├─ Left:
# │  │  │                 │  Triangle(id = 1316093791441037)
# │  │  │                 └─ Right:
# │  │  │                    Triangle(id = 310767789800692)
# │  │  └─ Right:
# │  │     BVH Node:
# │  │     ├─ Left:
# │  │     │  BVH Node:
# │  │     │  ├─ Left:
# │  │     │  │  BVH Node:
# │  │     │  │  ├─ Left:
# │  │     │  │  │  BVH Node:
# │  │     │  │  │  ├─ Left:
# │  │     │  │  │  │  BVH Node:
# │  │     │  │  │  │  ├─ Left:
# │  │     │  │  │  │  │  BVH Node:
# │  │     │  │  │  │  │  ├─ Left:
# │  │     │  │  │  │  │  │  Triangle(id = 8014435774284307)
# │  │     │  │  │  │  │  └─ Right:
# │  │     │  │  │  │  │     Triangle(id = 8014435774284307)
# │  │     │  │  │  │  └─ Right:
# │  │     │  │  │  │     BVH Node:
# │  │     │  │  │  │     ├─ Left:
# │  │     │  │  │  │     │  Triangle(id = 1577247615701100)
# │  │     │  │  │  │     └─ Right:
# │  │     │  │  │  │        Triangle(id = 2111554800558722)
# │  │     │  │  │  └─ Right:
# │  │     │  │  │     BVH Node:
# │  │     │  │  │     ├─ Left:
# │  │     │  │  │     │  BVH Node:
# │  │     │  │  │     │  ├─ Left:
# │  │     │  │  │     │  │  Triangle(id = 7744651964714728)
# │  │     │  │  │     │  └─ Right:
# │  │     │  │  │     │     Triangle(id = 1781804001438758)
# │  │     │  │  │     └─ Right:
# │  │     │  │  │        BVH Node:
# │  │     │  │  │        ├─ Left:
# │  │     │  │  │        │  Triangle(id = 5491971619610428)
# │  │     │  │  │        └─ Right:
# │  │     │  │  │           Triangle(id = 3767195315178516)
# │  │     │  │  └─ Right:
# │  │     │  │     BVH Node:
# │  │     │  │     ├─ Left:
# │  │     │  │     │  BVH Node:
# │  │     │  │     │  ├─ Left:
# │  │     │  │     │  │  BVH Node:
# │  │     │  │     │  │  ├─ Left:
# │  │     │  │     │  │  │  Triangle(id = 6007783435321100)
# │  │     │  │     │  │  └─ Right:
# │  │     │  │     │  │     Triangle(id = 9744150082761909)
# │  │     │  │     │  └─ Right:
# │  │     │  │     │     BVH Node:
# │  │     │  │     │     ├─ Left:
# │  │     │  │     │     │  Triangle(id = 1540137313054711)
# │  │     │  │     │     └─ Right:
# │  │     │  │     │        Triangle(id = 2183091090951544)
# │  │     │  │     └─ Right:
# │  │     │  │        BVH Node:
# │  │     │  │        ├─ Left:
# │  │     │  │        │  BVH Node:
# │  │     │  │        │  ├─ Left:
# │  │     │  │        │  │  Triangle(id = 5768506576716153)
# │  │     │  │        │  └─ Right:
# │  │     │  │        │     Triangle(id = 2065116138071543)
# │  │     │  │        └─ Right:
# │  │     │  │           BVH Node:
# │  │     │  │           ├─ Left:
# │  │     │  │           │  Triangle(id = 7978204729782164)
# │  │     │  │           └─ Right:
# │  │     │  │              Triangle(id = 2419138987074996)
# │  │     │  └─ Right:
# │  │     │     BVH Node:
# │  │     │     ├─ Left:
# │  │     │     │  BVH Node:
# │  │     │     │  ├─ Left:
# │  │     │     │  │  BVH Node:
# │  │     │     │  │  ├─ Left:
# │  │     │     │  │  │  BVH Node:
# │  │     │     │  │  │  ├─ Left:
# │  │     │     │  │  │  │  Triangle(id = 3854201217549168)
# │  │     │     │  │  │  └─ Right:
# │  │     │     │  │  │     Triangle(id = 3854201217549168)
# │  │     │     │  │  └─ Right:
# │  │     │     │  │     BVH Node:
# │  │     │     │  │     ├─ Left:
# │  │     │     │  │     │  Triangle(id = 7735681324832781)
# │  │     │     │  │     └─ Right:
# │  │     │     │  │        Triangle(id = 8317495682895370)
# │  │     │     │  └─ Right:
# │  │     │     │     BVH Node:
# │  │     │     │     ├─ Left:
# │  │     │     │     │  BVH Node:
# │  │     │     │     │  ├─ Left:
# │  │     │     │     │  │  Triangle(id = 64461204450163)
# │  │     │     │     │  └─ Right:
# │  │     │     │     │     Triangle(id = 1413884502137471)
# │  │     │     │     └─ Right:
# │  │     │     │        BVH Node:
# │  │     │     │        ├─ Left:
# │  │     │     │        │  Triangle(id = 3744411144370663)
# │  │     │     │        └─ Right:
# │  │     │     │           Triangle(id = 3806631850845915)
# │  │     │     └─ Right:
# │  │     │        BVH Node:
# │  │     │        ├─ Left:
# │  │     │        │  BVH Node:
# │  │     │        │  ├─ Left:
# │  │     │        │  │  BVH Node:
# │  │     │        │  │  ├─ Left:
# │  │     │        │  │  │  Triangle(id = 3264040723117611)
# │  │     │        │  │  └─ Right:
# │  │     │        │  │     Triangle(id = 5905251861310154)
# │  │     │        │  └─ Right:
# │  │     │        │     BVH Node:
# │  │     │        │     ├─ Left:
# │  │     │        │     │  Triangle(id = 111330696382562)
# │  │     │        │     └─ Right:
# │  │     │        │        Triangle(id = 4996448844950968)
# │  │     │        └─ Right:
# │  │     │           BVH Node:
# │  │     │           ├─ Left:
# │  │     │           │  BVH Node:
# │  │     │           │  ├─ Left:
# │  │     │           │  │  Triangle(id = 4555630803269107)
# │  │     │           │  └─ Right:
# │  │     │           │     Triangle(id = 5670817372606567)
# │  │     │           └─ Right:
# │  │     │              BVH Node:
# │  │     │              ├─ Left:
# │  │     │              │  Triangle(id = 4821700926002422)
# │  │     │              └─ Right:
# │  │     │                 Triangle(id = 4749497850585785)
# │  │     └─ Right:
# │  │        BVH Node:
# │  │        ├─ Left:
# │  │        │  BVH Node:
# │  │        │  ├─ Left:
# │  │        │  │  BVH Node:
# │  │        │  │  ├─ Left:
# │  │        │  │  │  BVH Node:
# │  │        │  │  │  ├─ Left:
# │  │        │  │  │  │  BVH Node:
# │  │        │  │  │  │  ├─ Left:
# │  │        │  │  │  │  │  Triangle(id = 7667111580745627)
# │  │        │  │  │  │  └─ Right:
# │  │        │  │  │  │     Triangle(id = 7667111580745627)
# │  │        │  │  │  └─ Right:
# │  │        │  │  │     BVH Node:
# │  │        │  │  │     ├─ Left:
# │  │        │  │  │     │  Triangle(id = 543187461980282)
# │  │        │  │  │     └─ Right:
# │  │        │  │  │        Triangle(id = 7377065511486038)
# │  │        │  │  └─ Right:
# │  │        │  │     BVH Node:
# │  │        │  │     ├─ Left:
# │  │        │  │     │  BVH Node:
# │  │        │  │     │  ├─ Left:
# │  │        │  │     │  │  Triangle(id = 1406484918090142)
# │  │        │  │     │  └─ Right:
# │  │        │  │     │     Triangle(id = 8293082629500243)
# │  │        │  │     └─ Right:
# │  │        │  │        BVH Node:
# │  │        │  │        ├─ Left:
# │  │        │  │        │  Triangle(id = 3076376186066042)
# │  │        │  │        └─ Right:
# │  │        │  │           Triangle(id = 8095894922247496)
# │  │        │  └─ Right:
# │  │        │     BVH Node:
# │  │        │     ├─ Left:
# │  │        │     │  BVH Node:
# │  │        │     │  ├─ Left:
# │  │        │     │  │  BVH Node:
# │  │        │     │  │  ├─ Left:
# │  │        │     │  │  │  Triangle(id = 3920560588634180)
# │  │        │     │  │  └─ Right:
# │  │        │     │  │     Triangle(id = 9361974658338750)
# │  │        │     │  └─ Right:
# │  │        │     │     BVH Node:
# │  │        │     │     ├─ Left:
# │  │        │     │     │  Triangle(id = 2962093297518937)
# │  │        │     │     └─ Right:
# │  │        │     │        Triangle(id = 1355852091701230)
# │  │        │     └─ Right:
# │  │        │        BVH Node:
# │  │        │        ├─ Left:
# │  │        │        │  BVH Node:
# │  │        │        │  ├─ Left:
# │  │        │        │  │  Triangle(id = 8202269750313801)
# │  │        │        │  └─ Right:
# │  │        │        │     Triangle(id = 9443753352951369)
# │  │        │        └─ Right:
# │  │        │           BVH Node:
# │  │        │           ├─ Left:
# │  │        │           │  Triangle(id = 1266900091545073)
# │  │        │           └─ Right:
# │  │        │              Triangle(id = 1085848033692893)
# │  │        └─ Right:
# │  │           BVH Node:
# │  │           ├─ Left:
# │  │           │  BVH Node:
# │  │           │  ├─ Left:
# │  │           │  │  BVH Node:
# │  │           │  │  ├─ Left:
# │  │           │  │  │  BVH Node:
# │  │           │  │  │  ├─ Left:
# │  │           │  │  │  │  Triangle(id = 7839375489460065)
# │  │           │  │  │  └─ Right:
# │  │           │  │  │     Triangle(id = 7839375489460065)
# │  │           │  │  └─ Right:
# │  │           │  │     BVH Node:
# │  │           │  │     ├─ Left:
# │  │           │  │     │  Triangle(id = 8300353538566944)
# │  │           │  │     └─ Right:
# │  │           │  │        Triangle(id = 1145035562167851)
# │  │           │  └─ Right:
# │  │           │     BVH Node:
# │  │           │     ├─ Left:
# │  │           │     │  BVH Node:
# │  │           │     │  ├─ Left:
# │  │           │     │  │  Triangle(id = 8517558615490492)
# │  │           │     │  └─ Right:
# │  │           │     │     Triangle(id = 2778895564651455)
# │  │           │     └─ Right:
# │  │           │        BVH Node:
# │  │           │        ├─ Left:
# │  │           │        │  Triangle(id = 4696213714105046)
# │  │           │        └─ Right:
# │  │           │           Triangle(id = 5517289206769076)
# │  │           └─ Right:
# │  │              BVH Node:
# │  │              ├─ Left:
# │  │              │  BVH Node:
# │  │              │  ├─ Left:
# │  │              │  │  BVH Node:
# │  │              │  │  ├─ Left:
# │  │              │  │  │  Triangle(id = 3881953086752242)
# │  │              │  │  └─ Right:
# │  │              │  │     Triangle(id = 7983775215487307)
# │  │              │  └─ Right:
# │  │              │     BVH Node:
# │  │              │     ├─ Left:
# │  │              │     │  Triangle(id = 1110571340815496)
# │  │              │     └─ Right:
# │  │              │        Triangle(id = 4341435988659715)
# │  │              └─ Right:
# │  │                 BVH Node:
# │  │                 ├─ Left:
# │  │                 │  BVH Node:
# │  │                 │  ├─ Left:
# │  │                 │  │  Triangle(id = 9701079613222714)
# │  │                 │  └─ Right:
# │  │                 │     Triangle(id = 4210205302882890)
# │  │                 └─ Right:
# │  │                    BVH Node:
# │  │                    ├─ Left:
# │  │                    │  Triangle(id = 9718272400955277)
# │  │                    └─ Right:
# │  │                       Triangle(id = 3485473497675619)
# │  └─ Right:
# │     BVH Node:
# │     ├─ Left:
# │     │  BVH Node:
# │     │  ├─ Left:
# │     │  │  BVH Node:
# │     │  │  ├─ Left:
# │     │  │  │  BVH Node:
# │     │  │  │  ├─ Left:
# │     │  │  │  │  BVH Node:
# │     │  │  │  │  ├─ Left:
# │     │  │  │  │  │  BVH Node:
# │     │  │  │  │  │  ├─ Left:
# │     │  │  │  │  │  │  BVH Node:
# │     │  │  │  │  │  │  ├─ Left:
# │     │  │  │  │  │  │  │  Triangle(id = 3188849919534305)
# │     │  │  │  │  │  │  └─ Right:
# │     │  │  │  │  │  │     Triangle(id = 3188849919534305)
# │     │  │  │  │  │  └─ Right:
# │     │  │  │  │  │     BVH Node:
# │     │  │  │  │  │     ├─ Left:
# │     │  │  │  │  │     │  Triangle(id = 3002871789029145)
# │     │  │  │  │  │     └─ Right:
# │     │  │  │  │  │        Triangle(id = 3103162236026523)
# │     │  │  │  │  └─ Right:
# │     │  │  │  │     BVH Node:
# │     │  │  │  │     ├─ Left:
# │     │  │  │  │     │  BVH Node:
# │     │  │  │  │     │  ├─ Left:
# │     │  │  │  │     │  │  Triangle(id = 6205347040428853)
# │     │  │  │  │     │  └─ Right:
# │     │  │  │  │     │     Triangle(id = 9612231087782292)
# │     │  │  │  │     └─ Right:
# │     │  │  │  │        BVH Node:
# │     │  │  │  │        ├─ Left:
# │     │  │  │  │        │  Triangle(id = 899874160243508)
# │     │  │  │  │        └─ Right:
# │     │  │  │  │           Triangle(id = 3859726353628665)
# │     │  │  │  └─ Right:
# │     │  │  │     BVH Node:
# │     │  │  │     ├─ Left:
# │     │  │  │     │  BVH Node:
# │     │  │  │     │  ├─ Left:
# │     │  │  │     │  │  BVH Node:
# │     │  │  │     │  │  ├─ Left:
# │     │  │  │     │  │  │  Triangle(id = 6113850445000133)
# │     │  │  │     │  │  └─ Right:
# │     │  │  │     │  │     Triangle(id = 6113850445000133)
# │     │  │  │     │  └─ Right:
# │     │  │  │     │     BVH Node:
# │     │  │  │     │     ├─ Left:
# │     │  │  │     │     │  Triangle(id = 1248219848329786)
# │     │  │  │     │     └─ Right:
# │     │  │  │     │        Triangle(id = 1573117147620715)
# │     │  │  │     └─ Right:
# │     │  │  │        BVH Node:
# │     │  │  │        ├─ Left:
# │     │  │  │        │  BVH Node:
# │     │  │  │        │  ├─ Left:
# │     │  │  │        │  │  Triangle(id = 6844151296199780)
# │     │  │  │        │  └─ Right:
# │     │  │  │        │     Triangle(id = 2769780910083739)
# │     │  │  │        └─ Right:
# │     │  │  │           BVH Node:
# │     │  │  │           ├─ Left:
# │     │  │  │           │  Triangle(id = 2207258930775138)
# │     │  │  │           └─ Right:
# │     │  │  │              Triangle(id = 3753690524559441)
# │     │  │  └─ Right:
# │     │  │     BVH Node:
# │     │  │     ├─ Left:
# │     │  │     │  BVH Node:
# │     │  │     │  ├─ Left:
# │     │  │     │  │  BVH Node:
# │     │  │     │  │  ├─ Left:
# │     │  │     │  │  │  BVH Node:
# │     │  │     │  │  │  ├─ Left:
# │     │  │     │  │  │  │  Triangle(id = 9608369871749351)
# │     │  │     │  │  │  └─ Right:
# │     │  │     │  │  │     Triangle(id = 9608369871749351)
# │     │  │     │  │  └─ Right:
# │     │  │     │  │     BVH Node:
# │     │  │     │  │     ├─ Left:
# │     │  │     │  │     │  Triangle(id = 140705063908387)
# │     │  │     │  │     └─ Right:
# │     │  │     │  │        Triangle(id = 386100779016058)
# │     │  │     │  └─ Right:
# │     │  │     │     BVH Node:
# │     │  │     │     ├─ Left:
# │     │  │     │     │  BVH Node:
# │     │  │     │     │  ├─ Left:
# │     │  │     │     │  │  Triangle(id = 1080709548855065)
# │     │  │     │     │  └─ Right:
# │     │  │     │     │     Triangle(id = 5080753680651806)
# │     │  │     │     └─ Right:
# │     │  │     │        BVH Node:
# │     │  │     │        ├─ Left:
# │     │  │     │        │  Triangle(id = 5368094718342180)
# │     │  │     │        └─ Right:
# │     │  │     │           Triangle(id = 3750743864943566)
# │     │  │     └─ Right:
# │     │  │        BVH Node:
# │     │  │        ├─ Left:
# │     │  │        │  BVH Node:
# │     │  │        │  ├─ Left:
# │     │  │        │  │  BVH Node:
# │     │  │        │  │  ├─ Left:
# │     │  │        │  │  │  Triangle(id = 9749501725415141)
# │     │  │        │  │  └─ Right:
# │     │  │        │  │     Triangle(id = 2372711532689148)
# │     │  │        │  └─ Right:
# │     │  │        │     BVH Node:
# │     │  │        │     ├─ Left:
# │     │  │        │     │  Triangle(id = 2034196968127288)
# │     │  │        │     └─ Right:
# │     │  │        │        Triangle(id = 90540367360181)
# │     │  │        └─ Right:
# │     │  │           BVH Node:
# │     │  │           ├─ Left:
# │     │  │           │  BVH Node:
# │     │  │           │  ├─ Left:
# │     │  │           │  │  Triangle(id = 5805208710702650)
# │     │  │           │  └─ Right:
# │     │  │           │     Triangle(id = 9188506727177044)
# │     │  │           └─ Right:
# │     │  │              BVH Node:
# │     │  │              ├─ Left:
# │     │  │              │  Triangle(id = 1914511587620938)
# │     │  │              └─ Right:
# │     │  │                 Triangle(id = 1462326917768561)
# │     │  └─ Right:
# │     │     BVH Node:
# │     │     ├─ Left:
# │     │     │  BVH Node:
# │     │     │  ├─ Left:
# │     │     │  │  BVH Node:
# │     │     │  │  ├─ Left:
# │     │     │  │  │  BVH Node:
# │     │     │  │  │  ├─ Left:
# │     │     │  │  │  │  BVH Node:
# │     │     │  │  │  │  ├─ Left:
# │     │     │  │  │  │  │  Triangle(id = 5601804516767614)
# │     │     │  │  │  │  └─ Right:
# │     │     │  │  │  │     Triangle(id = 5601804516767614)
# │     │     │  │  │  └─ Right:
# │     │     │  │  │     BVH Node:
# │     │     │  │  │     ├─ Left:
# │     │     │  │  │     │  Triangle(id = 1721961310255145)
# │     │     │  │  │     └─ Right:
# │     │     │  │  │        Triangle(id = 2368432780452201)
# │     │     │  │  └─ Right:
# │     │     │  │     BVH Node:
# │     │     │  │     ├─ Left:
# │     │     │  │     │  BVH Node:
# │     │     │  │     │  ├─ Left:
# │     │     │  │     │  │  Triangle(id = 4197796446650527)
# │     │     │  │     │  └─ Right:
# │     │     │  │     │     Triangle(id = 9229403776424445)
# │     │     │  │     └─ Right:
# │     │     │  │        BVH Node:
# │     │     │  │        ├─ Left:
# │     │     │  │        │  Triangle(id = 4128356724804862)
# │     │     │  │        └─ Right:
# │     │     │  │           Triangle(id = 8617589847488658)
# │     │     │  └─ Right:
# │     │     │     BVH Node:
# │     │     │     ├─ Left:
# │     │     │     │  BVH Node:
# │     │     │     │  ├─ Left:
# │     │     │     │  │  BVH Node:
# │     │     │     │  │  ├─ Left:
# │     │     │     │  │  │  Triangle(id = 1709202215641223)
# │     │     │     │  │  └─ Right:
# │     │     │     │  │     Triangle(id = 6548356421176724)
# │     │     │     │  └─ Right:
# │     │     │     │     BVH Node:
# │     │     │     │     ├─ Left:
# │     │     │     │     │  Triangle(id = 9301388408320895)
# │     │     │     │     └─ Right:
# │     │     │     │        Triangle(id = 7814458022718311)
# │     │     │     └─ Right:
# │     │     │        BVH Node:
# │     │     │        ├─ Left:
# │     │     │        │  BVH Node:
# │     │     │        │  ├─ Left:
# │     │     │        │  │  Triangle(id = 1581119342044486)
# │     │     │        │  └─ Right:
# │     │     │        │     Triangle(id = 7831751215208272)
# │     │     │        └─ Right:
# │     │     │           BVH Node:
# │     │     │           ├─ Left:
# │     │     │           │  Triangle(id = 9707253268040746)
# │     │     │           └─ Right:
# │     │     │              Triangle(id = 6454858528722968)
# │     │     └─ Right:
# │     │        BVH Node:
# │     │        ├─ Left:
# │     │        │  BVH Node:
# │     │        │  ├─ Left:
# │     │        │  │  BVH Node:
# │     │        │  │  ├─ Left:
# │     │        │  │  │  BVH Node:
# │     │        │  │  │  ├─ Left:
# │     │        │  │  │  │  Triangle(id = 4713332312789400)
# │     │        │  │  │  └─ Right:
# │     │        │  │  │     Triangle(id = 4713332312789400)
# │     │        │  │  └─ Right:
# │     │        │  │     BVH Node:
# │     │        │  │     ├─ Left:
# │     │        │  │     │  Triangle(id = 2664180837410389)
# │     │        │  │     └─ Right:
# │     │        │  │        Triangle(id = 4643066177976414)
# │     │        │  └─ Right:
# │     │        │     BVH Node:
# │     │        │     ├─ Left:
# │     │        │     │  BVH Node:
# │     │        │     │  ├─ Left:
# │     │        │     │  │  Triangle(id = 264928559361072)
# │     │        │     │  └─ Right:
# │     │        │     │     Triangle(id = 9542237787633387)
# │     │        │     └─ Right:
# │     │        │        BVH Node:
# │     │        │        ├─ Left:
# │     │        │        │  Triangle(id = 7457414555165132)
# │     │        │        └─ Right:
# │     │        │           Triangle(id = 7287211554593466)
# │     │        └─ Right:
# │     │           BVH Node:
# │     │           ├─ Left:
# │     │           │  BVH Node:
# │     │           │  ├─ Left:
# │     │           │  │  BVH Node:
# │     │           │  │  ├─ Left:
# │     │           │  │  │  Triangle(id = 9332906493155349)
# │     │           │  │  └─ Right:
# │     │           │  │     Triangle(id = 8870789947810829)
# │     │           │  └─ Right:
# │     │           │     BVH Node:
# │     │           │     ├─ Left:
# │     │           │     │  Triangle(id = 5986145326132624)
# │     │           │     └─ Right:
# │     │           │        Triangle(id = 633214545473079)
# │     │           └─ Right:
# │     │              BVH Node:
# │     │              ├─ Left:
# │     │              │  BVH Node:
# │     │              │  ├─ Left:
# │     │              │  │  Triangle(id = 9773807713766481)
# │     │              │  └─ Right:
# │     │              │     Triangle(id = 7170584825917134)
# │     │              └─ Right:
# │     │                 BVH Node:
# │     │                 ├─ Left:
# │     │                 │  Triangle(id = 1345064470985629)
# │     │                 └─ Right:
# │     │                    Triangle(id = 2961470240405036)
# │     └─ Right:
# │        BVH Node:
# │        ├─ Left:
# │        │  BVH Node:
# │        │  ├─ Left:
# │        │  │  BVH Node:
# │        │  │  ├─ Left:
# │        │  │  │  BVH Node:
# │        │  │  │  ├─ Left:
# │        │  │  │  │  BVH Node:
# │        │  │  │  │  ├─ Left:
# │        │  │  │  │  │  BVH Node:
# │        │  │  │  │  │  ├─ Left:
# │        │  │  │  │  │  │  Triangle(id = 5940837126263011)
# │        │  │  │  │  │  └─ Right:
# │        │  │  │  │  │     Triangle(id = 5940837126263011)
# │        │  │  │  │  └─ Right:
# │        │  │  │  │     BVH Node:
# │        │  │  │  │     ├─ Left:
# │        │  │  │  │     │  Triangle(id = 4074600213643042)
# │        │  │  │  │     └─ Right:
# │        │  │  │  │        Triangle(id = 7277630184075273)
# │        │  │  │  └─ Right:
# │        │  │  │     BVH Node:
# │        │  │  │     ├─ Left:
# │        │  │  │     │  BVH Node:
# │        │  │  │     │  ├─ Left:
# │        │  │  │     │  │  Triangle(id = 6524944448155462)
# │        │  │  │     │  └─ Right:
# │        │  │  │     │     Triangle(id = 9869066268815585)
# │        │  │  │     └─ Right:
# │        │  │  │        BVH Node:
# │        │  │  │        ├─ Left:
# │        │  │  │        │  Triangle(id = 1086327392377763)
# │        │  │  │        └─ Right:
# │        │  │  │           Triangle(id = 5720930186411930)
# │        │  │  └─ Right:
# │        │  │     BVH Node:
# │        │  │     ├─ Left:
# │        │  │     │  BVH Node:
# │        │  │     │  ├─ Left:
# │        │  │     │  │  BVH Node:
# │        │  │     │  │  ├─ Left:
# │        │  │     │  │  │  Triangle(id = 5360440473854355)
# │        │  │     │  │  └─ Right:
# │        │  │     │  │     Triangle(id = 182135947079752)
# │        │  │     │  └─ Right:
# │        │  │     │     BVH Node:
# │        │  │     │     ├─ Left:
# │        │  │     │     │  Triangle(id = 6017306418912342)
# │        │  │     │     └─ Right:
# │        │  │     │        Triangle(id = 1722901490865805)
# │        │  │     └─ Right:
# │        │  │        BVH Node:
# │        │  │        ├─ Left:
# │        │  │        │  BVH Node:
# │        │  │        │  ├─ Left:
# │        │  │        │  │  Triangle(id = 8149100861555529)
# │        │  │        │  └─ Right:
# │        │  │        │     Triangle(id = 7969532827601805)
# │        │  │        └─ Right:
# │        │  │           BVH Node:
# │        │  │           ├─ Left:
# │        │  │           │  Triangle(id = 5767741349128148)
# │        │  │           └─ Right:
# │        │  │              Triangle(id = 1652749392703137)
# │        │  └─ Right:
# │        │     BVH Node:
# │        │     ├─ Left:
# │        │     │  BVH Node:
# │        │     │  ├─ Left:
# │        │     │  │  BVH Node:
# │        │     │  │  ├─ Left:
# │        │     │  │  │  BVH Node:
# │        │     │  │  │  ├─ Left:
# │        │     │  │  │  │  Triangle(id = 5719881533604739)
# │        │     │  │  │  └─ Right:
# │        │     │  │  │     Triangle(id = 5719881533604739)
# │        │     │  │  └─ Right:
# │        │     │  │     BVH Node:
# │        │     │  │     ├─ Left:
# │        │     │  │     │  Triangle(id = 6040712173081371)
# │        │     │  │     └─ Right:
# │        │     │  │        Triangle(id = 2962739830700482)
# │        │     │  └─ Right:
# │        │     │     BVH Node:
# │        │     │     ├─ Left:
# │        │     │     │  BVH Node:
# │        │     │     │  ├─ Left:
# │        │     │     │  │  Triangle(id = 1803498181791800)
# │        │     │     │  └─ Right:
# │        │     │     │     Triangle(id = 5357728400943466)
# │        │     │     └─ Right:
# │        │     │        BVH Node:
# │        │     │        ├─ Left:
# │        │     │        │  Triangle(id = 5289382894348455)
# │        │     │        └─ Right:
# │        │     │           Triangle(id = 4177896960843321)
# │        │     └─ Right:
# │        │        BVH Node:
# │        │        ├─ Left:
# │        │        │  BVH Node:
# │        │        │  ├─ Left:
# │        │        │  │  BVH Node:
# │        │        │  │  ├─ Left:
# │        │        │  │  │  Triangle(id = 3836004235114692)
# │        │        │  │  └─ Right:
# │        │        │  │     Triangle(id = 4284896206601816)
# │        │        │  └─ Right:
# │        │        │     BVH Node:
# │        │        │     ├─ Left:
# │        │        │     │  Triangle(id = 1781541165538936)
# │        │        │     └─ Right:
# │        │        │        Triangle(id = 4433959588705641)
# │        │        └─ Right:
# │        │           BVH Node:
# │        │           ├─ Left:
# │        │           │  BVH Node:
# │        │           │  ├─ Left:
# │        │           │  │  Triangle(id = 7577909160682614)
# │        │           │  └─ Right:
# │        │           │     Triangle(id = 3355047454599230)
# │        │           └─ Right:
# │        │              BVH Node:
# │        │              ├─ Left:
# │        │              │  Triangle(id = 6370954227084103)
# │        │              └─ Right:
# │        │                 Triangle(id = 4839742926154467)
# │        └─ Right:
# │           BVH Node:
# │           ├─ Left:
# │           │  BVH Node:
# │           │  ├─ Left:
# │           │  │  BVH Node:
# │           │  │  ├─ Left:
# │           │  │  │  BVH Node:
# │           │  │  │  ├─ Left:
# │           │  │  │  │  BVH Node:
# │           │  │  │  │  ├─ Left:
# │           │  │  │  │  │  Triangle(id = 5070526174876076)
# │           │  │  │  │  └─ Right:
# │           │  │  │  │     Triangle(id = 5070526174876076)
# │           │  │  │  └─ Right:
# │           │  │  │     BVH Node:
# │           │  │  │     ├─ Left:
# │           │  │  │     │  Triangle(id = 6192552086552138)
# │           │  │  │     └─ Right:
# │           │  │  │        Triangle(id = 7599826835823661)
# │           │  │  └─ Right:
# │           │  │     BVH Node:
# │           │  │     ├─ Left:
# │           │  │     │  BVH Node:
# │           │  │     │  ├─ Left:
# │           │  │     │  │  Triangle(id = 1760137453554466)
# │           │  │     │  └─ Right:
# │           │  │     │     Triangle(id = 5193963440390772)
# │           │  │     └─ Right:
# │           │  │        BVH Node:
# │           │  │        ├─ Left:
# │           │  │        │  Triangle(id = 873281493725352)
# │           │  │        └─ Right:
# │           │  │           Triangle(id = 8939867423378131)
# │           │  └─ Right:
# │           │     BVH Node:
# │           │     ├─ Left:
# │           │     │  BVH Node:
# │           │     │  ├─ Left:
# │           │     │  │  BVH Node:
# │           │     │  │  ├─ Left:
# │           │     │  │  │  Triangle(id = 2485653736841285)
# │           │     │  │  └─ Right:
# │           │     │  │     Triangle(id = 941758340743196)
# │           │     │  └─ Right:
# │           │     │     BVH Node:
# │           │     │     ├─ Left:
# │           │     │     │  Triangle(id = 1390597433561896)
# │           │     │     └─ Right:
# │           │     │        Triangle(id = 7072627792054032)
# │           │     └─ Right:
# │           │        BVH Node:
# │           │        ├─ Left:
# │           │        │  BVH Node:
# │           │        │  ├─ Left:
# │           │        │  │  Triangle(id = 2307519394523626)
# │           │        │  └─ Right:
# │           │        │     Triangle(id = 2558737575773024)
# │           │        └─ Right:
# │           │           BVH Node:
# │           │           ├─ Left:
# │           │           │  Triangle(id = 2198726085447843)
# │           │           └─ Right:
# │           │              Triangle(id = 7948456513817417)
# │           └─ Right:
# │              BVH Node:
# │              ├─ Left:
# │              │  BVH Node:
# │              │  ├─ Left:
# │              │  │  BVH Node:
# │              │  │  ├─ Left:
# │              │  │  │  BVH Node:
# │              │  │  │  ├─ Left:
# │              │  │  │  │  Triangle(id = 5080088706575447)
# │              │  │  │  └─ Right:
# │              │  │  │     Triangle(id = 5080088706575447)
# │              │  │  └─ Right:
# │              │  │     BVH Node:
# │              │  │     ├─ Left:
# │              │  │     │  Triangle(id = 1838738136223351)
# │              │  │     └─ Right:
# │              │  │        Triangle(id = 2095670785341720)
# │              │  └─ Right:
# │              │     BVH Node:
# │              │     ├─ Left:
# │              │     │  BVH Node:
# │              │     │  ├─ Left:
# │              │     │  │  Triangle(id = 5659265268197507)
# │              │     │  └─ Right:
# │              │     │     Triangle(id = 6814584083820471)
# │              │     └─ Right:
# │              │        BVH Node:
# │              │        ├─ Left:
# │              │        │  Triangle(id = 8102781649885519)
# │              │        └─ Right:
# │              │           Triangle(id = 3659431696477007)
# │              └─ Right:
# │                 BVH Node:
# │                 ├─ Left:
# │                 │  BVH Node:
# │                 │  ├─ Left:
# │                 │  │  BVH Node:
# │                 │  │  ├─ Left:
# │                 │  │  │  Triangle(id = 8703723182301425)
# │                 │  │  └─ Right:
# │                 │  │     Triangle(id = 6666152148865773)
# │                 │  └─ Right:
# │                 │     BVH Node:
# │                 │     ├─ Left:
# │                 │     │  Triangle(id = 3778330116280300)
# │                 │     └─ Right:
# │                 │        Triangle(id = 5771340844009108)
# │                 └─ Right:
# │                    BVH Node:
# │                    ├─ Left:
# │                    │  BVH Node:
# │                    │  ├─ Left:
# │                    │  │  Triangle(id = 5441470203490568)
# │                    │  └─ Right:
# │                    │     Triangle(id = 2201988802284772)
# │                    └─ Right:
# │                       BVH Node:
# │                       ├─ Left:
# │                       │  Triangle(id = 4145586737961662)
# │                       └─ Right:
# │                          Triangle(id = 4483346614887157)
# └─ Right:
#    BVH Node:
#    ├─ Left:
#    │  BVH Node:
#    │  ├─ Left:
#    │  │  BVH Node:
#    │  │  ├─ Left:
#    │  │  │  BVH Node:
#    │  │  │  ├─ Left:
#    │  │  │  │  BVH Node:
#    │  │  │  │  ├─ Left:
#    │  │  │  │  │  BVH Node:
#    │  │  │  │  │  ├─ Left:
#    │  │  │  │  │  │  BVH Node:
#    │  │  │  │  │  │  ├─ Left:
#    │  │  │  │  │  │  │  BVH Node:
#    │  │  │  │  │  │  │  ├─ Left:
#    │  │  │  │  │  │  │  │  Triangle(id = 6034359693948607)
#    │  │  │  │  │  │  │  └─ Right:
#    │  │  │  │  │  │  │     Triangle(id = 6034359693948607)
#    │  │  │  │  │  │  └─ Right:
#    │  │  │  │  │  │     BVH Node:
#    │  │  │  │  │  │     ├─ Left:
#    │  │  │  │  │  │     │  Triangle(id = 4842386657448707)
#    │  │  │  │  │  │     └─ Right:
#    │  │  │  │  │  │        Triangle(id = 9613636086022921)
#    │  │  │  │  │  └─ Right:
#    │  │  │  │  │     BVH Node:
#    │  │  │  │  │     ├─ Left:
#    │  │  │  │  │     │  BVH Node:
#    │  │  │  │  │     │  ├─ Left:
#    │  │  │  │  │     │  │  Triangle(id = 974373907849168)
#    │  │  │  │  │     │  └─ Right:
#    │  │  │  │  │     │     Triangle(id = 7558211043866149)
#    │  │  │  │  │     └─ Right:
#    │  │  │  │  │        BVH Node:
#    │  │  │  │  │        ├─ Left:
#    │  │  │  │  │        │  Triangle(id = 3083919314715882)
#    │  │  │  │  │        └─ Right:
#    │  │  │  │  │           Triangle(id = 3274853411356575)
#    │  │  │  │  └─ Right:
#    │  │  │  │     BVH Node:
#    │  │  │  │     ├─ Left:
#    │  │  │  │     │  BVH Node:
#    │  │  │  │     │  ├─ Left:
#    │  │  │  │     │  │  BVH Node:
#    │  │  │  │     │  │  ├─ Left:
#    │  │  │  │     │  │  │  Triangle(id = 5837110284633185)
#    │  │  │  │     │  │  └─ Right:
#    │  │  │  │     │  │     Triangle(id = 5837110284633185)
#    │  │  │  │     │  └─ Right:
#    │  │  │  │     │     BVH Node:
#    │  │  │  │     │     ├─ Left:
#    │  │  │  │     │     │  Triangle(id = 5152767728458919)
#    │  │  │  │     │     └─ Right:
#    │  │  │  │     │        Triangle(id = 7416814713399026)
#    │  │  │  │     └─ Right:
#    │  │  │  │        BVH Node:
#    │  │  │  │        ├─ Left:
#    │  │  │  │        │  BVH Node:
#    │  │  │  │        │  ├─ Left:
#    │  │  │  │        │  │  Triangle(id = 1867563029407766)
#    │  │  │  │        │  └─ Right:
#    │  │  │  │        │     Triangle(id = 1202562432241917)
#    │  │  │  │        └─ Right:
#    │  │  │  │           BVH Node:
#    │  │  │  │           ├─ Left:
#    │  │  │  │           │  Triangle(id = 7075744768439325)
#    │  │  │  │           └─ Right:
#    │  │  │  │              Triangle(id = 9437721542218029)
#    │  │  │  └─ Right:
#    │  │  │     BVH Node:
#    │  │  │     ├─ Left:
#    │  │  │     │  BVH Node:
#    │  │  │     │  ├─ Left:
#    │  │  │     │  │  BVH Node:
#    │  │  │     │  │  ├─ Left:
#    │  │  │     │  │  │  BVH Node:
#    │  │  │     │  │  │  ├─ Left:
#    │  │  │     │  │  │  │  Triangle(id = 1701537616672799)
#    │  │  │     │  │  │  └─ Right:
#    │  │  │     │  │  │     Triangle(id = 1701537616672799)
#    │  │  │     │  │  └─ Right:
#    │  │  │     │  │     BVH Node:
#    │  │  │     │  │     ├─ Left:
#    │  │  │     │  │     │  Triangle(id = 7819204051754898)
#    │  │  │     │  │     └─ Right:
#    │  │  │     │  │        Triangle(id = 2537968145943063)
#    │  │  │     │  └─ Right:
#    │  │  │     │     BVH Node:
#    │  │  │     │     ├─ Left:
#    │  │  │     │     │  BVH Node:
#    │  │  │     │     │  ├─ Left:
#    │  │  │     │     │  │  Triangle(id = 3855259688149154)
#    │  │  │     │     │  └─ Right:
#    │  │  │     │     │     Triangle(id = 5296904099314613)
#    │  │  │     │     └─ Right:
#    │  │  │     │        BVH Node:
#    │  │  │     │        ├─ Left:
#    │  │  │     │        │  Triangle(id = 5246363498520383)
#    │  │  │     │        └─ Right:
#    │  │  │     │           Triangle(id = 7933527143297500)
#    │  │  │     └─ Right:
#    │  │  │        BVH Node:
#    │  │  │        ├─ Left:
#    │  │  │        │  BVH Node:
#    │  │  │        │  ├─ Left:
#    │  │  │        │  │  BVH Node:
#    │  │  │        │  │  ├─ Left:
#    │  │  │        │  │  │  Triangle(id = 9431460297443110)
#    │  │  │        │  │  └─ Right:
#    │  │  │        │  │     Triangle(id = 7490129653010159)
#    │  │  │        │  └─ Right:
#    │  │  │        │     BVH Node:
#    │  │  │        │     ├─ Left:
#    │  │  │        │     │  Triangle(id = 3719395978229949)
#    │  │  │        │     └─ Right:
#    │  │  │        │        Triangle(id = 9641756214295877)
#    │  │  │        └─ Right:
#    │  │  │           BVH Node:
#    │  │  │           ├─ Left:
#    │  │  │           │  BVH Node:
#    │  │  │           │  ├─ Left:
#    │  │  │           │  │  Triangle(id = 9720244230555798)
#    │  │  │           │  └─ Right:
#    │  │  │           │     Triangle(id = 9295988435139041)
#    │  │  │           └─ Right:
#    │  │  │              BVH Node:
#    │  │  │              ├─ Left:
#    │  │  │              │  Triangle(id = 2540493607141079)
#    │  │  │              └─ Right:
#    │  │  │                 Triangle(id = 511503498175823)
#    │  │  └─ Right:
#    │  │     BVH Node:
#    │  │     ├─ Left:
#    │  │     │  BVH Node:
#    │  │     │  ├─ Left:
#    │  │     │  │  BVH Node:
#    │  │     │  │  ├─ Left:
#    │  │     │  │  │  BVH Node:
#    │  │     │  │  │  ├─ Left:
#    │  │     │  │  │  │  BVH Node:
#    │  │     │  │  │  │  ├─ Left:
#    │  │     │  │  │  │  │  Triangle(id = 7008867615932757)
#    │  │     │  │  │  │  └─ Right:
#    │  │     │  │  │  │     Triangle(id = 7008867615932757)
#    │  │     │  │  │  └─ Right:
#    │  │     │  │  │     BVH Node:
#    │  │     │  │  │     ├─ Left:
#    │  │     │  │  │     │  Triangle(id = 9165388106140853)
#    │  │     │  │  │     └─ Right:
#    │  │     │  │  │        Triangle(id = 1472911108019164)
#    │  │     │  │  └─ Right:
#    │  │     │  │     BVH Node:
#    │  │     │  │     ├─ Left:
#    │  │     │  │     │  BVH Node:
#    │  │     │  │     │  ├─ Left:
#    │  │     │  │     │  │  Triangle(id = 215709065349325)
#    │  │     │  │     │  └─ Right:
#    │  │     │  │     │     Triangle(id = 1885665098508427)
#    │  │     │  │     └─ Right:
#    │  │     │  │        BVH Node:
#    │  │     │  │        ├─ Left:
#    │  │     │  │        │  Triangle(id = 1068038496083737)
#    │  │     │  │        └─ Right:
#    │  │     │  │           Triangle(id = 6295784153853538)
#    │  │     │  └─ Right:
#    │  │     │     BVH Node:
#    │  │     │     ├─ Left:
#    │  │     │     │  BVH Node:
#    │  │     │     │  ├─ Left:
#    │  │     │     │  │  BVH Node:
#    │  │     │     │  │  ├─ Left:
#    │  │     │     │  │  │  Triangle(id = 8439977215065345)
#    │  │     │     │  │  └─ Right:
#    │  │     │     │  │     Triangle(id = 4820072506854894)
#    │  │     │     │  └─ Right:
#    │  │     │     │     BVH Node:
#    │  │     │     │     ├─ Left:
#    │  │     │     │     │  Triangle(id = 1638741059546522)
#    │  │     │     │     └─ Right:
#    │  │     │     │        Triangle(id = 1212565183446590)
#    │  │     │     └─ Right:
#    │  │     │        BVH Node:
#    │  │     │        ├─ Left:
#    │  │     │        │  BVH Node:
#    │  │     │        │  ├─ Left:
#    │  │     │        │  │  Triangle(id = 264824258234349)
#    │  │     │        │  └─ Right:
#    │  │     │        │     Triangle(id = 4553284415014666)
#    │  │     │        └─ Right:
#    │  │     │           BVH Node:
#    │  │     │           ├─ Left:
#    │  │     │           │  Triangle(id = 7757316050394449)
#    │  │     │           └─ Right:
#    │  │     │              Triangle(id = 3726840692042069)
#    │  │     └─ Right:
#    │  │        BVH Node:
#    │  │        ├─ Left:
#    │  │        │  BVH Node:
#    │  │        │  ├─ Left:
#    │  │        │  │  BVH Node:
#    │  │        │  │  ├─ Left:
#    │  │        │  │  │  BVH Node:
#    │  │        │  │  │  ├─ Left:
#    │  │        │  │  │  │  Triangle(id = 9336060242384922)
#    │  │        │  │  │  └─ Right:
#    │  │        │  │  │     Triangle(id = 9336060242384922)
#    │  │        │  │  └─ Right:
#    │  │        │  │     BVH Node:
#    │  │        │  │     ├─ Left:
#    │  │        │  │     │  Triangle(id = 8298119762683341)
#    │  │        │  │     └─ Right:
#    │  │        │  │        Triangle(id = 4977565607820354)
#    │  │        │  └─ Right:
#    │  │        │     BVH Node:
#    │  │        │     ├─ Left:
#    │  │        │     │  BVH Node:
#    │  │        │     │  ├─ Left:
#    │  │        │     │  │  Triangle(id = 5956449718038206)
#    │  │        │     │  └─ Right:
#    │  │        │     │     Triangle(id = 2574920490989932)
#    │  │        │     └─ Right:
#    │  │        │        BVH Node:
#    │  │        │        ├─ Left:
#    │  │        │        │  Triangle(id = 3971885093577364)
#    │  │        │        └─ Right:
#    │  │        │           Triangle(id = 8054384483036473)
#    │  │        └─ Right:
#    │  │           BVH Node:
#    │  │           ├─ Left:
#    │  │           │  BVH Node:
#    │  │           │  ├─ Left:
#    │  │           │  │  BVH Node:
#    │  │           │  │  ├─ Left:
#    │  │           │  │  │  Triangle(id = 998255774312003)
#    │  │           │  │  └─ Right:
#    │  │           │  │     Triangle(id = 741596191127459)
#    │  │           │  └─ Right:
#    │  │           │     BVH Node:
#    │  │           │     ├─ Left:
#    │  │           │     │  Triangle(id = 7759706218918654)
#    │  │           │     └─ Right:
#    │  │           │        Triangle(id = 7435815818985090)
#    │  │           └─ Right:
#    │  │              BVH Node:
#    │  │              ├─ Left:
#    │  │              │  BVH Node:
#    │  │              │  ├─ Left:
#    │  │              │  │  Triangle(id = 5222245397204576)
# ...
#       │  │     │     │     Triangle(id = 1938165348177211)
#       │  │     │     └─ Right:
#       │  │     │        BVH Node:
#       │  │     │        ├─ Left:
#       │  │     │        │  Triangle(id = 2622053435547887)
#       │  │     │        └─ Right:
#       │  │     │           Triangle(id = 2693926612444008)
#       │  │     └─ Right:
#       │  │        BVH Node:
#       │  │        ├─ Left:
#       │  │        │  BVH Node:
#       │  │        │  ├─ Left:
#       │  │        │  │  BVH Node:
#       │  │        │  │  ├─ Left:
#       │  │        │  │  │  Triangle(id = 318773845470980)
#       │  │        │  │  └─ Right:
#       │  │        │  │     Triangle(id = 5694410896686087)
#       │  │        │  └─ Right:
#       │  │        │     BVH Node:
#       │  │        │     ├─ Left:
#       │  │        │     │  Triangle(id = 4145572716798574)
#       │  │        │     └─ Right:
#       │  │        │        Triangle(id = 1865635710283235)
#       │  │        └─ Right:
#       │  │           BVH Node:
#       │  │           ├─ Left:
#       │  │           │  BVH Node:
#       │  │           │  ├─ Left:
#       │  │           │  │  Triangle(id = 976508772285999)
#       │  │           │  └─ Right:
#       │  │           │     Triangle(id = 3278262130833814)
#       │  │           └─ Right:
#       │  │              BVH Node:
#       │  │              ├─ Left:
#       │  │              │  Triangle(id = 4407468817919672)
#       │  │              └─ Right:
#       │  │                 Triangle(id = 9865039641566958)
#       │  └─ Right:
#       │     BVH Node:
#       │     ├─ Left:
#       │     │  BVH Node:
#       │     │  ├─ Left:
#       │     │  │  BVH Node:
#       │     │  │  ├─ Left:
#       │     │  │  │  BVH Node:
#       │     │  │  │  ├─ Left:
#       │     │  │  │  │  BVH Node:
#       │     │  │  │  │  ├─ Left:
#       │     │  │  │  │  │  Triangle(id = 8384113250538471)
#       │     │  │  │  │  └─ Right:
#       │     │  │  │  │     Triangle(id = 8384113250538471)
#       │     │  │  │  └─ Right:
#       │     │  │  │     BVH Node:
#       │     │  │  │     ├─ Left:
#       │     │  │  │     │  Triangle(id = 5611414911546475)
#       │     │  │  │     └─ Right:
#       │     │  │  │        Triangle(id = 1992180055360423)
#       │     │  │  └─ Right:
#       │     │  │     BVH Node:
#       │     │  │     ├─ Left:
#       │     │  │     │  BVH Node:
#       │     │  │     │  ├─ Left:
#       │     │  │     │  │  Triangle(id = 3729147494333021)
#       │     │  │     │  └─ Right:
#       │     │  │     │     Triangle(id = 2503003021021927)
#       │     │  │     └─ Right:
#       │     │  │        BVH Node:
#       │     │  │        ├─ Left:
#       │     │  │        │  Triangle(id = 8101588197823675)
#       │     │  │        └─ Right:
#       │     │  │           Triangle(id = 5785966670833693)
#       │     │  └─ Right:
#       │     │     BVH Node:
#       │     │     ├─ Left:
#       │     │     │  BVH Node:
#       │     │     │  ├─ Left:
#       │     │     │  │  BVH Node:
#       │     │     │  │  ├─ Left:
#       │     │     │  │  │  Triangle(id = 3600307640338852)
#       │     │     │  │  └─ Right:
#       │     │     │  │     Triangle(id = 7192983656807116)
#       │     │     │  └─ Right:
#       │     │     │     BVH Node:
#       │     │     │     ├─ Left:
#       │     │     │     │  Triangle(id = 1077579900832100)
#       │     │     │     └─ Right:
#       │     │     │        Triangle(id = 864542369567476)
#       │     │     └─ Right:
#       │     │        BVH Node:
#       │     │        ├─ Left:
#       │     │        │  BVH Node:
#       │     │        │  ├─ Left:
#       │     │        │  │  Triangle(id = 1841784334850221)
#       │     │        │  └─ Right:
#       │     │        │     Triangle(id = 565280677819463)
#       │     │        └─ Right:
#       │     │           BVH Node:
#       │     │           ├─ Left:
#       │     │           │  Triangle(id = 4177086615465700)
#       │     │           └─ Right:
#       │     │              Triangle(id = 7805573485242155)
#       │     └─ Right:
#       │        BVH Node:
#       │        ├─ Left:
#       │        │  BVH Node:
#       │        │  ├─ Left:
#       │        │  │  BVH Node:
#       │        │  │  ├─ Left:
#       │        │  │  │  BVH Node:
#       │        │  │  │  ├─ Left:
#       │        │  │  │  │  Triangle(id = 5775597133315687)
#       │        │  │  │  └─ Right:
#       │        │  │  │     Triangle(id = 5775597133315687)
#       │        │  │  └─ Right:
#       │        │  │     BVH Node:
#       │        │  │     ├─ Left:
#       │        │  │     │  Triangle(id = 9121591919248529)
#       │        │  │     └─ Right:
#       │        │  │        Triangle(id = 2536355464057061)
#       │        │  └─ Right:
#       │        │     BVH Node:
#       │        │     ├─ Left:
#       │        │     │  BVH Node:
#       │        │     │  ├─ Left:
#       │        │     │  │  Triangle(id = 5357934216206595)
#       │        │     │  └─ Right:
#       │        │     │     Triangle(id = 2218223666281933)
#       │        │     └─ Right:
#       │        │        BVH Node:
#       │        │        ├─ Left:
#       │        │        │  Triangle(id = 6816039919276622)
#       │        │        └─ Right:
#       │        │           Triangle(id = 5631466528785769)
#       │        └─ Right:
#       │           BVH Node:
#       │           ├─ Left:
#       │           │  BVH Node:
#       │           │  ├─ Left:
#       │           │  │  BVH Node:
#       │           │  │  ├─ Left:
#       │           │  │  │  Triangle(id = 6590561176431747)
#       │           │  │  └─ Right:
#       │           │  │     Triangle(id = 2791355818949835)
#       │           │  └─ Right:
#       │           │     BVH Node:
#       │           │     ├─ Left:
#       │           │     │  Triangle(id = 5595495392683916)
#       │           │     └─ Right:
#       │           │        Triangle(id = 7388973338582461)
#       │           └─ Right:
#       │              BVH Node:
#       │              ├─ Left:
#       │              │  BVH Node:
#       │              │  ├─ Left:
#       │              │  │  Triangle(id = 8489577443981988)
#       │              │  └─ Right:
#       │              │     Triangle(id = 9297630150040178)
#       │              └─ Right:
#       │                 BVH Node:
#       │                 ├─ Left:
#       │                 │  Triangle(id = 2175016712450527)
#       │                 └─ Right:
#       │                    Triangle(id = 3884895854935290)
#       └─ Right:
#          BVH Node:
#          ├─ Left:
#          │  BVH Node:
#          │  ├─ Left:
#          │  │  BVH Node:
#          │  │  ├─ Left:
#          │  │  │  BVH Node:
#          │  │  │  ├─ Left:
#          │  │  │  │  BVH Node:
#          │  │  │  │  ├─ Left:
#          │  │  │  │  │  BVH Node:
#          │  │  │  │  │  ├─ Left:
#          │  │  │  │  │  │  Triangle(id = 8244771855999739)
#          │  │  │  │  │  └─ Right:
#          │  │  │  │  │     Triangle(id = 8244771855999739)
#          │  │  │  │  └─ Right:
#          │  │  │  │     BVH Node:
#          │  │  │  │     ├─ Left:
#          │  │  │  │     │  Triangle(id = 8733152612477643)
#          │  │  │  │     └─ Right:
#          │  │  │  │        Triangle(id = 8508346227353808)
#          │  │  │  └─ Right:
#          │  │  │     BVH Node:
#          │  │  │     ├─ Left:
#          │  │  │     │  BVH Node:
#          │  │  │     │  ├─ Left:
#          │  │  │     │  │  Triangle(id = 3749265461819578)
#          │  │  │     │  └─ Right:
#          │  │  │     │     Triangle(id = 3426130777816887)
#          │  │  │     └─ Right:
#          │  │  │        BVH Node:
#          │  │  │        ├─ Left:
#          │  │  │        │  Triangle(id = 3153675255081819)
#          │  │  │        └─ Right:
#          │  │  │           Triangle(id = 541297494415593)
#          │  │  └─ Right:
#          │  │     BVH Node:
#          │  │     ├─ Left:
#          │  │     │  BVH Node:
#          │  │     │  ├─ Left:
#          │  │     │  │  BVH Node:
#          │  │     │  │  ├─ Left:
#          │  │     │  │  │  Triangle(id = 1941686972764444)
#          │  │     │  │  └─ Right:
#          │  │     │  │     Triangle(id = 1488673604385627)
#          │  │     │  └─ Right:
#          │  │     │     BVH Node:
#          │  │     │     ├─ Left:
#          │  │     │     │  Triangle(id = 7530781296554696)
#          │  │     │     └─ Right:
#          │  │     │        Triangle(id = 8245239290776907)
#          │  │     └─ Right:
#          │  │        BVH Node:
#          │  │        ├─ Left:
#          │  │        │  BVH Node:
#          │  │        │  ├─ Left:
#          │  │        │  │  Triangle(id = 3479563853569377)
#          │  │        │  └─ Right:
#          │  │        │     Triangle(id = 9298352335349003)
#          │  │        └─ Right:
#          │  │           BVH Node:
#          │  │           ├─ Left:
#          │  │           │  Triangle(id = 7271558523291087)
#          │  │           └─ Right:
#          │  │              Triangle(id = 6669303650913677)
#          │  └─ Right:
#          │     BVH Node:
#          │     ├─ Left:
#          │     │  BVH Node:
#          │     │  ├─ Left:
#          │     │  │  BVH Node:
#          │     │  │  ├─ Left:
#          │     │  │  │  BVH Node:
#          │     │  │  │  ├─ Left:
#          │     │  │  │  │  Triangle(id = 9705219540249863)
#          │     │  │  │  └─ Right:
#          │     │  │  │     Triangle(id = 9705219540249863)
#          │     │  │  └─ Right:
#          │     │  │     BVH Node:
#          │     │  │     ├─ Left:
#          │     │  │     │  Triangle(id = 9024891709422263)
#          │     │  │     └─ Right:
#          │     │  │        Triangle(id = 9758999783394554)
#          │     │  └─ Right:
#          │     │     BVH Node:
#          │     │     ├─ Left:
#          │     │     │  BVH Node:
#          │     │     │  ├─ Left:
#          │     │     │  │  Triangle(id = 1690571772043924)
#          │     │     │  └─ Right:
#          │     │     │     Triangle(id = 6125565364426355)
#          │     │     └─ Right:
#          │     │        BVH Node:
#          │     │        ├─ Left:
#          │     │        │  Triangle(id = 2264037587979285)
#          │     │        └─ Right:
#          │     │           Triangle(id = 5036406705650594)
#          │     └─ Right:
#          │        BVH Node:
#          │        ├─ Left:
#          │        │  BVH Node:
#          │        │  ├─ Left:
#          │        │  │  BVH Node:
#          │        │  │  ├─ Left:
#          │        │  │  │  Triangle(id = 5654522588359532)
#          │        │  │  └─ Right:
#          │        │  │     Triangle(id = 5622090287027265)
#          │        │  └─ Right:
#          │        │     BVH Node:
#          │        │     ├─ Left:
#          │        │     │  Triangle(id = 1949608627286751)
#          │        │     └─ Right:
#          │        │        Triangle(id = 5934095339355619)
#          │        └─ Right:
#          │           BVH Node:
#          │           ├─ Left:
#          │           │  BVH Node:
#          │           │  ├─ Left:
#          │           │  │  Triangle(id = 7329026522788611)
#          │           │  └─ Right:
#          │           │     Triangle(id = 9373972823351296)
#          │           └─ Right:
#          │              BVH Node:
#          │              ├─ Left:
#          │              │  Triangle(id = 5569676388927885)
#          │              └─ Right:
#          │                 Triangle(id = 2973427090188609)
#          └─ Right:
#             BVH Node:
#             ├─ Left:
#             │  BVH Node:
#             │  ├─ Left:
#             │  │  BVH Node:
#             │  │  ├─ Left:
#             │  │  │  BVH Node:
#             │  │  │  ├─ Left:
#             │  │  │  │  BVH Node:
#             │  │  │  │  ├─ Left:
#             │  │  │  │  │  Triangle(id = 1125552624509288)
#             │  │  │  │  └─ Right:
#             │  │  │  │     Triangle(id = 1125552624509288)
#             │  │  │  └─ Right:
#             │  │  │     BVH Node:
#             │  │  │     ├─ Left:
#             │  │  │     │  Triangle(id = 8698526916710641)
#             │  │  │     └─ Right:
#             │  │  │        Triangle(id = 6729347598555456)
#             │  │  └─ Right:
#             │  │     BVH Node:
#             │  │     ├─ Left:
#             │  │     │  BVH Node:
#             │  │     │  ├─ Left:
#             │  │     │  │  Triangle(id = 2730382353195616)
#             │  │     │  └─ Right:
#             │  │     │     Triangle(id = 5900155612455355)
#             │  │     └─ Right:
#             │  │        BVH Node:
#             │  │        ├─ Left:
#             │  │        │  Triangle(id = 1822426821492299)
#             │  │        └─ Right:
#             │  │           Triangle(id = 2954707036022112)
#             │  └─ Right:
#             │     BVH Node:
#             │     ├─ Left:
#             │     │  BVH Node:
#             │     │  ├─ Left:
#             │     │  │  BVH Node:
#             │     │  │  ├─ Left:
#             │     │  │  │  Triangle(id = 2475608575223655)
#             │     │  │  └─ Right:
#             │     │  │     Triangle(id = 5315774675953119)
#             │     │  └─ Right:
#             │     │     BVH Node:
#             │     │     ├─ Left:
#             │     │     │  Triangle(id = 5260675574663679)
#             │     │     └─ Right:
#             │     │        Triangle(id = 1693757406810320)
#             │     └─ Right:
#             │        BVH Node:
#             │        ├─ Left:
#             │        │  BVH Node:
#             │        │  ├─ Left:
#             │        │  │  Triangle(id = 5691014947336523)
#             │        │  └─ Right:
#             │        │     Triangle(id = 2714684516356653)
#             │        └─ Right:
#             │           BVH Node:
#             │           ├─ Left:
#             │           │  Triangle(id = 5907594791912843)
#             │           └─ Right:
#             │              Triangle(id = 5952043592430058)
#             └─ Right:
#                BVH Node:
#                ├─ Left:
#                │  BVH Node:
#                │  ├─ Left:
#                │  │  BVH Node:
#                │  │  ├─ Left:
#                │  │  │  BVH Node:
#                │  │  │  ├─ Left:
#                │  │  │  │  Triangle(id = 6025824068376571)
#                │  │  │  └─ Right:
#                │  │  │     Triangle(id = 6025824068376571)
#                │  │  └─ Right:
#                │  │     BVH Node:
#                │  │     ├─ Left:
#                │  │     │  Triangle(id = 439696722741838)
#                │  │     └─ Right:
#                │  │        Triangle(id = 1698718953412704)
#                │  └─ Right:
#                │     BVH Node:
#                │     ├─ Left:
#                │     │  BVH Node:
#                │     │  ├─ Left:
#                │     │  │  Triangle(id = 6995039102282838)
#                │     │  └─ Right:
#                │     │     Triangle(id = 6864007000430094)
#                │     └─ Right:
#                │        BVH Node:
#                │        ├─ Left:
#                │        │  Triangle(id = 3060244311097225)
#                │        └─ Right:
#                │           Triangle(id = 3960532573616982)
#                └─ Right:
#                   BVH Node:
#                   ├─ Left:
#                   │  BVH Node:
#                   │  ├─ Left:
#                   │  │  BVH Node:
#                   │  │  ├─ Left:
#                   │  │  │  Triangle(id = 3510014409215133)
#                   │  │  └─ Right:
#                   │  │     Triangle(id = 6720018778163548)
#                   │  └─ Right:
#                   │     BVH Node:
#                   │     ├─ Left:
#                   │     │  Triangle(id = 7581420246827773)
#                   │     └─ Right:
#                   │        Triangle(id = 2043284451142917)
#                   └─ Right:
#                      BVH Node:
#                      ├─ Left:
#                      │  BVH Node:
#                      │  ├─ Left:
#                      │  │  Triangle(id = 5401270509363947)
#                      │  └─ Right:
#                      │     Triangle(id = 4190425838386908)
#                      └─ Right:
#                         BVH Node:
#                         ├─ Left:
#                         │  Triangle(id = 1109970050544949)
#                         └─ Right:
#                            Triangle(id = 3872737836528911)
# Node list length: 512
# World object list length: 478

# %%
tri_to_id(tri_l) = map(x -> x.id, tri_l)

tl1 = tri_to_id(node_list)
tl2 = tri_to_id(world_obj_list)

println("Tri list 1: ", tl1)
println("Tri list 2: ", tl2)

# remove duplicates from both 
tl1 = unique(tl1)
tl2 = unique(tl2)

println("triangles to render ", length(tl1))
println("actual number of triangles ", length(tl2))

# %%
common_ids = intersect(tl1, tl2)
setdiff(tl2, tl1)

for t in world_l.objects
    if t.id in setdiff(tl2, tl1)
        println("Triangle not in BVH: ", t.A, t.B, t.C)
    end
end
